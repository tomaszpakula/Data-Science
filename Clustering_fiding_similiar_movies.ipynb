# %% [markdown]
# <a href="https://colab.research.google.com/github/tomaszpakula/Data-Science/blob/main/Clustering_fiding_similiar_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!gdown 15SSBsuO9ap-kheYtsLJwBhJ8NKeVmhRr
# !gdown 1hI4TOtDkUhivThGoXetFYI_iPj2jmF8i
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hI4TOtDkUhivThGoXetFYI_iPj2jmF8i
# To: /content/movies_metadata.csv
# 100% 34.4M/34.4M [00:00<00:00, 73.7MB/s]

# %%
import pandas as pd
import numpy as np
import spacy
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import pairwise_distances
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer

# %%
movies = pd.read_csv("movies_metadata.csv")
movies['overview'] = movies['overview'].fillna('')
movies['original title'] = movies['original_title'].drop_duplicates()
movies.head()
# Out:
# <ipython-input-72-3cb07b3197f7>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv("movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...      revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status  \
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  \
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                 original title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
# [5 rows x 25 columns]

# %%
vectorizer = TfidfVectorizer(stop_words='english')
matrix = vectorizer.fit_transform(movies['overview'])

# %%
names = vectorizer.get_feature_names_out()

# %%
print(movies[movies['original_title']=='Spider-Man']['overview'])
index = movies[movies['original_title']=='Spider-Man'].index
# Out:
# 5215    After being bitten by a genetically altered sp...
# Name: overview, dtype: object

# %%
movies['cosine distance'] = cosine_distances(matrix, matrix[index])
movies.sort_values(by = "cosine distance" , ascending = True).head(15)[['original_title', 'overview', 'cosine distance']]
# Out:
#                   original_title  \
# 5215                  Spider-Man
# 11780               Spider-Man 3
# 23187   The Amazing Spider-Man 2
# 9350         Immortel (ad vitam)
# 19129     The Amazing Spider-Man
# 43704                    Phoenix
# 7909                Spider-Man 2
# 2584               Arachnophobia
# 1895   Gremlins 2: The New Batch
# 40428                    ねらわれた学園
# 40390                    Mamaboy
# 43743           Spider-Plant Man
# 19507                    The Lie
# 42114                         가시
# 42394                  钟馗伏魔：雪妖魔灵
#
#                                                 overview  cosine distance
# 5215   After being bitten by a genetically altered sp...         0.000000
# 11780  The seemingly invincible Spider-Man goes up ag...         0.726992
# 23187  For Peter Parker, life is busy. Between taking...         0.767204
# 9350   New York City in the year 2095 where genetical...         0.777720
# 19129  Peter Parker is an outcast high schooler aband...         0.782681
# 43704  When a mining colony is taken over by genetica...         0.786443
# 7909   Peter Parker is going through a major identity...         0.797333
# 2584   A large spider from the jungles of South Ameri...         0.806161
# 1895   Young sweethearts Billy and Kate move to the B...         0.829216
# 40428  Mitamura Yuka is a normal, shy high school stu...         0.830156
# 40390  A high school student must hide the fact that ...         0.830688
# 43743  Spider-Plant Man is a parody of Spider-Man, ma...         0.835002
# 19507  A man's life is altered unexpectedly after tel...         0.835150
# 42114  A high school student develops a crush on her ...         0.845836
# 42394  The story of Chinese legendary anti-hero Zhong...         0.846830

# %%
def top_words(title):
    dic = {'word': [], 'tf-idf': []}
    index  = movies[movies['original_title']==title].head(1).index
    for i in range(matrix.shape[1]):
      if matrix[index,i]>0:
        dic['word'].append(names[i])
        dic['tf-idf'].append(float(str(matrix[index,i]).split('\t')[1]))
    df = pd.DataFrame(dic)
    df.set_index('word',inplace = True)

    return df.sort_values(by='tf-idf',ascending=False)

# %%
spiderman = top_words('Spider-Man')

# %%
movies[movies['original_title'] == 'Iron Man']['original_title']
# Out:
# 12588    Iron Man
# 34647    Iron Man
# 41787    Iron Man
# Name: original_title, dtype: object

# %%
common_words = spiderman.join(top_words('Spider-Man 3'), lsuffix='_Spider', rsuffix='_Spider3')
common_words = common_words.sort_values(by='tf-idf_Spider3', ascending=False).head(5)
common_words.fillna(0)
# Out:
#          tf-idf_Spider  tf-idf_Spider3
# word
# spider        0.307082        0.391061
# altered       0.315852        0.201115
# parker        0.292749        0.186405
# peter         0.233874        0.148917
# endowed       0.366595        0.000000

# %%
common_words = spiderman.join(top_words('Immortel (ad vitam)'), lsuffix='_Spider', rsuffix='_Immortel')
common_words = common_words.sort_values(by='tf-idf_Immortel', ascending=False).head(5)
common_words.fillna(0)
# Out:
#              tf-idf_Spider  tf-idf_Immortel
# word
# genetically       0.317868         0.351867
# altered           0.315852         0.349635
# endowed           0.366595         0.000000
# bitten            0.325871         0.000000
# nerdy             0.317868         0.000000

# %%
common_words = spiderman.join(top_words('Iron Man'), lsuffix='_Spider', rsuffix='_Iron')
common_words = common_words.sort_values(by='tf-idf_Iron', ascending=False).head(5)
common_words.fillna(0)
# Out:
#              tf-idf_Spider  tf-idf_Iron
# word
# endowed           0.366595          0.0
# bitten            0.325871          0.0
# genetically       0.317868          0.0
# nerdy             0.317868          0.0
# altered           0.315852          0.0

# %%
model = KMeans()

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'original title', 'cosine distance'],
#       dtype='object')

# %%
movies['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
def convert(row):
  text = ""
  for dict in row:
    text += "".join(dict['name']) + " "
  return text

# %%
movies['genres'] = movies['genres'].apply(literal_eval).apply(convert)
#movies['genres']

# %%
count_vectorizer = CountVectorizer(stop_words='english')
count_matrix = count_vectorizer.fit_transform(movies['genres'])

# %%
movies['cosine distance genres'] = cosine_distances(count_matrix, count_matrix[index])
movies.sort_values(by = "cosine distance genres" , ascending = True).head(15)[['original_title', 'overview', 'genres', 'cosine distance', 'cosine distance genres']]
# Out:
#                                 original_title  \
# 5215                                Spider-Man
# 1328                            Batman Returns
# 40057                                     封神传奇
# 38128           Wizards of the Lost Kingdom II
# 14218                                      Ink
# 43                               Mortal Kombat
# 12706                                  Hancock
# 26096                    Jack the Giant Killer
# 39681                                 李三腳威震地獄門
# 11180                               笑傲江湖II東方不敗
# 30796                                    Cross
# 26143  Le amazzoni - donne d'amore e di guerra
# 35592               Chandu on the Magic Island
# 30825                           Avengers Grimm
# 18584                                     白蛇传说
#
#                                                 overview           genres  \
# 5215   After being bitten by a genetically altered sp...  Fantasy Action
# 1328   Having defeated the Joker, Batman now faces th...  Action Fantasy
# 40057  During the reign of King Zhou (Tony Leung Ka-f...  Action Fantasy
# 38128                                 No overview found.  Action Fantasy
# 14218  Invisible forces exert power over us in our sl...  Action Fantasy
# 43     For nine generations an evil sorcerer has been...  Action Fantasy
# 12706  Hancock is a down-and-out superhero who's forc...  Fantasy Action
# 26096  A giant beanstalk brings Jack to a land in the...  Action Fantasy
# 39681  Everyone's favorite martial artist ""Bruce"" w...  Fantasy Action
# 11180  Jet Li plays Ling, a student from the Blue Mou...  Action Fantasy
# 30796  Given incredible power by an ancient Celtic Cr...  Action Fantasy
# 26143  A tribe of vicious female warriors terrorizes ...  Fantasy Action
# 35592  The second of two feature films edited from th...  Fantasy Action
# 30825  When Rumpelstiltskin destroys the Magic Mirror...  Action Fantasy
# 18584  The Sorcerer and the White Snake is an ancient...  Action Fantasy
#
#        cosine distance  cosine distance genres
# 5215          0.000000            2.220446e-16
# 1328          1.000000            2.220446e-16
# 40057         1.000000            2.220446e-16
# 38128         1.000000            2.220446e-16
# 14218         1.000000            2.220446e-16
# 43            1.000000            2.220446e-16
# 12706         1.000000            2.220446e-16
# 26096         1.000000            2.220446e-16
# 39681         1.000000            2.220446e-16
# 11180         0.952259            2.220446e-16
# 30796         1.000000            2.220446e-16
# 26143         1.000000            2.220446e-16
# 35592         0.985105            2.220446e-16
# 30825         0.883465            2.220446e-16
# 18584         1.000000            2.220446e-16
